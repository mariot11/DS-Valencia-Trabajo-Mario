# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# Ejercicio if/else

# %%
mi_nota_de_examen = "-1"

if ((type(mi_nota_de_examen) != int) or mi_nota_de_examen < 0 or mi_nota_de_examen > 10):
    print("Nota erronea")

elif mi_nota_de_examen < 5 :
    print("A septiembre :(")

elif mi_nota_de_examen < 6 :
    print("Suficiente")

elif mi_nota_de_examen < 7 :
    print("Bien")

elif mi_nota_de_examen < 9 :
    print("Notable")

else:
    print("Sobresaliente")
# Out:
# Nota erronea

# %% [markdown]
# ## Ejercicio 1
# Dada la siguiente lista:
# > ```ejer_1 = [1,2,3,4,5]```
#
# Inviértela para que quede de la siguiente manera
# > ```ejer_1 = [5,4,3,2,1]```

# %%
ejer_1 = [1,2,3,4,5]
print(ejer_1)

ejer_1.reverse()
print(ejer_1)
# Out:
# [1, 2, 3, 4, 5]
# [5, 4, 3, 2, 1]

# %% [markdown]
# ## Ejercicio 2
# Eleva todos los elementos de la lista al cuadrado
# > ```ejer_2 = [1,2,3,4,5]```

# %%
ejer_2 = [1,2,3,4,5]
print(ejer_2)
ejer_2_copia = ejer_2.copy()

for i in range(len(ejer_2_copia)):
    ejer_2_copia[i] = ejer_2_copia[i]**2

print(ejer_2_copia)
# Out:
# [1, 2, 3, 4, 5]
# [1, 4, 9, 16, 25]

# %% [markdown]
# ## Ejercicio 3
# Crea una lista nueva con todas las combinaciones de las siguientes dos listas:
# > ```ejer_3_1 = ["Hola", "amigo"]```
# >
# > ```ejer_3_2 = ["Que", "tal"]```
#
# Obten el siguiente output:
#
# ['Hola Que', 'Hola tal', 'amigo Que', 'amigo tal']

# %%
ejer_3_1 = ["Hola", "amigo"]
ejer_3_2 = ["Que", "tal"]

ejer_3_3 = []

for palabra1 in ejer_3_1:
    for palabra2 in ejer_3_2:
        ejer_3_3.append(palabra1 + " " + palabra2)

print(ejer_3_3)
# Out:
# ['Hola Que', 'Hola tal', 'amigo Que', 'amigo tal']

# %% [markdown]
# ## Ejercicio 4
# Dada la siguiente lista, encuentra el índice del valor 45 y sustitúyelo por el 0
# > ```ejer_4 = [20, 47, 19, 29, 45, 67, 78, 90]```

# %%
ejer_4 = [20, 47, 19, 29, 45, 67, 78, 90]
print(ejer_4)

indice45 = ejer_4.index(45)
print(indice45)

ejer_4[indice45] = 0
print(ejer_4)
# Out:
# [20, 47, 19, 29, 45, 67, 78, 90]
# 4
# [20, 47, 19, 29, 0, 67, 78, 90]

# %% [markdown]
# ## Ejercicio 5
# Dada la siguiente lista, elimina todos los valores iguales a 3
# > ```ejer_5 = [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3]```
#
# Consejo: No intentes eliminar elementos sobre la lista que estás iterando. Haz una copia con `ejer_5.copy()`.

# %%
ejer_5 = [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3]
print(ejer_5)
ejer_5_copia = ejer_5.copy()


for i in ejer_5:
    if (i == 3):
        ejer_5_copia.remove(3)

print(ejer_5_copia)
# Out:
# [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3]
# [20, 47, 19, 29, 45, 67, 78, 90]

# %% [markdown]
# ## Ejercicio 6
# 1. Crea una tupla con 3 elementos
# 2. Crea otra tupla con un elemento y comprueba su tipo
# 3. Crea una tupla con elementos de diferentes tipos
# 4. Imprime por pantalla el primer y ultimo elemento de la tupla del apartado 3. Usa `len` para el ultimo
# 5. Añade un elemento a la tupla del apartado 3.
# 6. Eliminar un elemento de la tupla del apartado 5, que se encuentre más o menos en la mitad.
# 7. Convierte la tupla del apartado 5 en una lista

# %%
tupla1 = (1, 2, 3, 4)
print(tupla1)
tupla2 = (4,)
print(tupla2)
print(type(tupla2))
tupla3 = ("casa", True, 0.01, 1080)
print(tupla3)
print(tupla3[0], tupla3[len(tupla3)-1])
tupla4 = tupla3 + tupla2
print(tupla4)

mitad = len(tupla4) // 2
lista1 = list(tupla4)
lista1.pop(mitad)
tupla5 = tuple(lista1)
tupla6 = tupla4[:mitad] + tupla4[mitad + 1:]
print(tupla6)
print(tupla5)
print(lista1)
# Out:
# (1, 2, 3, 4)
# (4,)
# <class 'tuple'>
# ('casa', True, 0.01, 1080)
# casa 1080
# ('casa', True, 0.01, 1080, 4)
# ('casa', True, 1080, 4)
# ('casa', True, 1080, 4)
# ['casa', True, 1080, 4]

# %% [markdown]
# ## Ejercicio 7
# Concatena todos los elementos de la tupla en un unico string. Para ello utiliza el metodo `.join()` de los Strings
# > ```ejer_7 = ("cien", "cañones", "por", "banda")```
#
# Resultado: `cien cañones por banda`

# %%
ejer_7 = ("cien", "cañones", "por", "banda")
print(" ".join(ejer_7))
# Out:
# cien cañones por banda

# %% [markdown]
# ## Ejercicio 8
# Obten el tercer elemento de la siguiente tupla, y el tercero empezando por la cola
# > ```ejer_8 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3)```

# %%
ejer_8 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3)
print(ejer_8[2], ejer_8[-3])
# Out:
# 3 90

# %% [markdown]
# ## Ejercicio 9
# 1. ¿Cuántas veces se repite el 3 en la siguiente tupla?
# 2. Crea una tupla nueva con los elementos desde la posicion 5 a la 10.
# 3. ¿Cuántos elementos tiene la tupla `ejer_9`?
# > ```ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)```

# %%
ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)
print(ejer_9)
print(ejer_9.count(3))
print("numero total de elementos", len( ejer_9))
set1 = set(ejer_9)
print("elementos diferentes", len(set1))
# Out:
# (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)
# 7
# numero total de elementos 26
# elementos diferentes 15

# %% [markdown]
# ## Ejercicio 10
# Comprueba si el numero 60 esta en la tupla del ejercicio 9

# %%
aparece60 = False
for num in ejer_9:
    if num == 60:
        aparece60 = True
        break
print(aparece60)

# 60 in ejer_9
# Out:
# False

# %% [markdown]
# ## Ejercicio 11
# 1. Convierte la tupla del apartado 10 en una lista
# 2. Convierte la tupla del apartado 10 en un set
# 3. Convierte la tupla del apartado 10 en un diccionario. Usa también los indices

# %%
print(ejer_9)
lista = list(ejer_9)
print(lista)
set1 = set(ejer_9)
print(set1)

diccionario = {}
for i in range(len(ejer_9)):
    diccionario.update({i:ejer_9[i]})
print(diccionario)
# Out:
# (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)
# [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7]
# {2, 3, 67, 5, 4, 7, 6, 9, 45, 78, 47, 19, 20, 90, 29}
# {0: 3, 1: 20, 2: 3, 3: 47, 4: 19, 5: 3, 6: 29, 7: 45, 8: 67, 9: 78, 10: 90, 11: 3, 12: 3, 13: 5, 14: 2, 15: 4, 16: 7, 17: 9, 18: 4, 19: 2, 20: 4, 21: 3, 22: 3, 23: 4, 24: 6, 25: 7}

# %% [markdown]
# ## Ejercicio 12
# Convierte la siguiente tupla en un diccionario
# > ```ejer_12 = [("x", 1), ("x", 2), ("x", 3), ("y", 1), ("y", 2), ("z", 1)]```
#
# TIP: Puedes usar dos variables de control en un bucle `for`. Una por cada valor de las tuplas.

# %%
ejer_12 = [("x", 1), ("x", 2), ("x", 3), ("y", 1), ("y", 2), ("z", 1)]
diccionario = {}
for i,j in ejer_12:
    if(i not in diccionario):
        diccionario[i] = [j]
    else:
        diccionario[i].append(j)

print(diccionario)
# Out:
# {'x': [1, 2, 3], 'y': [1, 2], 'z': [1]}

# %% [markdown]
# ## Ejercicio 13
# 1. Crea una lista ordenada ascendente con las claves del diccionario
# 2. Crea otra lista ordenada descendente con los valores
# 3. Añade una nueva clave/valor
# 4. Busca la clave 2 dentro del diccionario
# 5. Itera la clave y el valor del diccionario con un unico for
# > ```ejer_13 = {4:78, 2:98, 8:234, 5:29}```

# %%
ejer_13 = {4:78, 2:98, 8:234, 5:29}

lista1 = list(ejer_13.keys())
lista1.sort()
print(lista1)

lista2 = list(ejer_13.values())
lista2.sort(reverse = True)
print(lista2)
# Out:
# [2, 4, 5, 8]
# [234, 98, 78, 29]

# %% [markdown]
# ## Ejercicio 14
# Junta ambos diccionarios. Para ello, utiliza `update`
# > ```ejer_14_1 = {1: 11, 2: 22}```
# >
# > ```ejer_14_2 = {3: 33, 4: 44}```

# %%
ejer_14_1 = {1: 11, 2: 22}
ejer_14_2 = {3: 33, 4: 44}

ejer_14_1.update(ejer_14_2.items())

print(ejer_14_1)
# Out:
# {1: 11, 2: 22, 3: 33, 4: 44}

# %% [markdown]
# ## Ejercicio 15
# Suma todos los valores del dicionario
# > ```ejer_15 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}```

# %%
ejer_15 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}

sum_list = ejer_15.values()
resultado_suma = sum(sum_list)
print(resultado_suma)
# Out:
# 165

# %% [markdown]
# ## Ejercicio 16
# Multiplica todos los valores del diccionario
# > ```ejer_16 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}```

# %%
ejer_16 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}
lista = ejer_16.values()

multiplicacion = 1

for num in lista:
    multiplicacion = num * multiplicacion

print(multiplicacion)
# Out:
# 19326120

# %% [markdown]
# ## Ejercicio 17
# 1. Crea un set de tres elementos
# 2. Añade un cuarto
# 3. Elimina el utlimo elemento añadido
# 4. Elimina el elemento 10, si está presente. Usa `discard()`

# %%
set_17 = {1, 2, 3}
print(set_17)
set_17.add(4)
print(set_17)
set_17.pop() #esto está mal
print(set_17)
set_17.add(10)
print(set_17)
set_17.discard(10)
print(set_17)
# Out:
# {1, 2, 3}
# {1, 2, 3, 4}
# {2, 3, 4}
# {2, 3, 4, 10}
# {2, 3, 4}

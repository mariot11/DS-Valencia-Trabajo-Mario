# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics I

# %% [markdown]
# ## Ejercicio 1
# Imprime por pantalla esta cita con el siguiente formato
#
# ![imagen](./img/frase_Einstein.PNG)

# %%
print('¿Por qué esta magnífica tecnología científica,\n\tque ahorra trabajo y nos hace la vida mas fácil,\n\t\tnos aporta tan poca felicidad?\n\t\t\tLa respuesta es está, simplemente: porque aún no hemos aprendido a usarla con tino.\n"Albert Einstein"')
# Out:
# ¿Por qué esta magnífica tecnología científica,
# 	que ahorra trabajo y nos hace la vida mas fácil,
# 		nos aporta tan poca felicidad?
# 			La respuesta es está, simplemente: porque aún no hemos aprendido a usarla con tino.
# "Albert Einstein"

# %% [markdown]
# ## Ejercicio 2
# 1. Escribe el nombre de la calle de tu domicilio
# 2. Escribe el numero de la calle en otra
# 3. Población en una tercera
# 4. Codigo postal en la cuarta variable
# 5. Crea una quinta variable que concatene todas ellas
# 6. Imprimela por pantalla

# %%
nombre_calle = input("Escribe el nombre de la calle de tu domicilio")
numero = input("Escribe el número de tu domicilio")
poblacion = input("Escribe el nombre de tu población")
codigo_postal = input("Escribe tu código postal")

direccion = nombre_calle + " " + numero + ", " + poblacion + " " + codigo_postal

print(direccion)
# Out:
# Calle Hierros 27, Valencia 46022

# %% [markdown]
# ## Ejercicio 3
# Replica el output del ejercicio dos, pero está vez sin usar una variable intermedia que concatene todas las demas. Realiza este ejercicio en una línea, con un  único `print`

# %%
print(nombre_calle + " " + numero + ", " + poblacion + " " + codigo_postal)
# Out:
# Calle Hierros 27, Valencia 46022

# %% [markdown]
# ## Ejercicio 4
# ¿Qué variables están mal escritas y por qué? Realiza primero tu hipótesis y luego ejecuta las variables para comprobarlo. En ese orden :)
#
#
# 1. mi_variable = "Economía"
# 2. otra_var = "Ejercicio #Mal
# 3. True = "Ejercicio" #Mal
# 4. mi variab1e = "Alpha" #Mal
# 5. exec = True
# 6. import = 40 #Mal
# 7. 81mi_variable = "Agua" #Mal
# 8. mi_variable10 = 6

# %%
True = "holla"
# Out:
#   Cell In[12], line 1
#     True = "holla"
#     ^
# SyntaxError: cannot assign to True

# %%
mi_variable = "Economía"
otra_var = "Ejercicio #Mal
True = "Ejercicio" #Mal
mi variab1e = "Alpha" #Mal
exec = True
import = 40 #Mal
81mi_variable = "Agua" #Mal
mi_variable10 = 6
# Out:
#   Cell In[19], line 7
#     81mi_variable = "Agua" #Mal
#      ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# ## Ejercicio 5
# Realiza un conversor de grados Celsius a Fahrenheit. El conversor tiene que recibir el input del usuario y devolver la conversión.
#
# La conversión de grados sigue la siguiente fórmula: F = (C × 9 / 5) + 32

# %%
celsius = float(input("Introduce los grados en Celsius que quieres convertir a Farenheit"))

farenheit = (celsius * 9 / 5) + 32

print(farenheit)
# Out:
# 98.6

# %% [markdown]
# ## Ejercicio 6
# Comenta en la medida de lo posible el Ejercicio 5. Será suficiente con poner al menos un comentario de línea, y otro multilínea

# %%
#pedimos al usuario que introduzca los datos iniciales
celsius = float(input("Introduce los grados en Celsius que quieres convertir a Farenheit"))

farenheit = (celsius * 9 / 5) + 32

"""
Hacemos la operación de conversión
imprimimos el resultado
"""

print(farenheit)
# Out:
# El equivalente en grados Fahrenheit es 41.0
